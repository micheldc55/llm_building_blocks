# %%
import re

# %%
with open("/Users/davidovichm/Desktop/placeholder_michel_folder/llm_building_blocks/data/tokenizers/pride_and_prejudice.txt", "r") as file:
    text = file.read()


print(len(text))
# Out:
# 748124

# %%
print(text[:100]) # empieza en idx 1500
# Out:
# The Project Gutenberg eBook of Pride and Prejudice
#
# This ebook is for the use of anyone anywhere

# %%
from src.tokenizers.base_tokenizers import RegularExpressionTokenizer

tokenizer = RegularExpressionTokenizer(pattern=r'\s+|[,.?!"\'\-_()]+|[^\s,.?!"\'\-_()]+')
tokenizer.fit(["Hello, world!", "Hello, world!", "Oh, my god!"])
print(tokenizer.vocab)
print(tokenizer.encode("Hello, world!"))
# print(tokenizer.decode([4, 5, 6, 7, 8]))
# Out:
# {'<PAD>': 0, '<UNK>': 1, '<BOS>': 2, '<EOS>': 3, 'Hello': 4, ',': 5, ' ': 6, 'world': 7, '!': 8, 'Oh': 9, 'my': 10, 'god': 11}

# %%
print(tokenizer.vocab)
# Out:
# {'<PAD>': 0, '<UNK>': 1, '<BOS>': 2, '<EOS>': 3, 'Hello': 4, ',': 5, ' ': 6, 'world': 7, '!': 8, 'Oh': 9, 'my': 10, 'god': 11}

# %%
print(tokenizer.encode("Hello, world!"))
# Out:
# [4, 5, 6, 7, 8]

# %%
print(tokenizer.vocab)
# Out:
# {'<PAD>': 0, '<UNK>': 1, '<BOS>': 2, '<EOS>': 3, 'Hello': 4, ',': 5, ' ': 6, 'world': 7, '!': 8, 'Oh': 9, 'my': 10, 'god': 11}

# %%
tokenizer.decode([4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tokenizer.decode([4])
#
# File ~/Desktop/placeholder_michel_folder/llm_building_blocks/src/tokenizers/base_tokenizers.py:41, in RegularExpressionTokenizer.decode(self, token_ids)
#      39 def decode(self, token_ids: list[int] | int) -> str:
#      40     if isinstance(token_ids, list):
# ---> 41         return "".join(self.vocab.idx_to_vocab[token_id] for token_id in token_ids)
#      42     else:
#      43         return self.vocab.idx_to_vocab[token_ids]
#
# File ~/Desktop/placeholder_michel_folder/llm_building_blocks/src/tokenizers/base_tokenizers.py:41, in <genexpr>(.0)
#      39 def decode(self, token_ids: list[int] | int) -> str:
#      40     if isinstance(token_ids, list):
# ---> 41         return "".join(self.vocab.idx_to_vocab[token_id] for token_id in token_ids)
#      42     else:
# ...
